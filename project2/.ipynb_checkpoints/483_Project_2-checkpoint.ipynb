# %%
import numpy as np
from sklearn import tree 
import pandas as pd
import os
import io
import numpy as np
import pandas as pd
from pandas import DataFrame
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB

df = pd.read_csv('Dataset.csv', header = None, skipinitialspace=True)
df.columns = ["age", "class", "education", "years", "married", "occupation", "relationship", "gender","gain", "loss","hours", "income"]

# %%
df.head()
# Out:
#    age             class        education               years  \
# 0  Age        Work Class  Education Level  Years of education
# 1   39         State-gov        Bachelors                  13
# 2   50  Self-emp-not-inc        Bachelors                  13
# 3   38           Private          HS-grad                   9
# 4   53           Private             11th                   7
#
#               married         occupation   relationship  gender          gain  \
# 0      Marital Status         Occupation   Relationship  Gender  Captial Gain
# 1       Never-married       Adm-clerical  Not-in-family    Male          2174
# 2  Married-civ-spouse    Exec-managerial        Husband    Male             0
# 3            Divorced  Handlers-cleaners  Not-in-family    Male             0
# 4  Married-civ-spouse  Handlers-cleaners        Husband    Male             0
#
#            loss           hours  income
# 0  Capital Loss  Hours-per-week  Income
# 1             0              40   <=50K
# 2             0              13   <=50K
# 3             0              40   <=50K
# 4             0              40   <=50K

# %%
wc = {'Private' : 0, 'Self-emp-not-inc' : 1, 'Self-emp-inc' : 2, 'Federal-gov' : 3, 'Local-gov' : 4, 'State-gov' : 5, 'Without-pay' : 6, 'Never-worked' : 7}
df['class'] = df['class'].map(wc)

el = {'Bachelors' : 0, 'Some-college' : 1, '11th' : 2, 'HS-grad' : 3, 'Prof-school' : 4, 'Assoc-acdm' : 5, 'Assoc-voc' : 6, '9th' : 7, '7th-8th' : 8, '12th' : 9, 'Masters' : 10, '1st-4th' : 11, '10th' : 12, 'Doctorate' : 13, '5th-6th' : 14, 'Preschool' : 15}
df['education'] = df['education'].map(el)

ms = {'Married-civ-spouse' : 0, 'Divorced' : 1, 'Never-married' : 2, 'Separated' : 3, 'Widowed' : 4, 'Married-spouse-absent' : 5, 'Married-AF-spouse' : 6}
df['married'] = df['married'].map(ms)

oc = {'Tech-support' : 0, 'Craft-repair' : 1, 'Other-service' : 2, 'Sales' : 3, 'Exec-managerial' : 4, 'Prof-specialty' : 5, 'Handlers-cleaners' : 6, 'Machine-op-inspct' : 7, 'Adm-clerical' : 8, 'Farm-fishing' : 9, 'Transport-moving' : 10, 'Priv-house-serv' : 11, 'Protective-serv' : 12, 'Armed-Forces' : 13}
df['occupation'] = df['occupation'].map(oc)

rp = {'Wife' : 0, 'Own-child' : 1, 'Husband' : 2, 'Not-in-family' : 3, 'Other-relative' : 4, 'Unmarried' : 5}
df['relationship'] = df['relationship'].map(rp)

gd = {'Female' : 0, 'Male' : 1}
df['gender'] = df['gender'].map(gd)

ic = {'>50K' : 0, '<=50K' : 1}
df['income'] = df['income'].map(ic)
df = df.dropna()
df.head()
# Out:
#   age  class  education years  married  occupation  relationship  gender  \
# 1  39    5.0        0.0    13      2.0         8.0           3.0     1.0
# 2  50    1.0        0.0    13      0.0         4.0           2.0     1.0
# 3  38    0.0        3.0     9      1.0         6.0           3.0     1.0
# 4  53    0.0        2.0     7      0.0         6.0           2.0     1.0
# 5  28    0.0        0.0    13      0.0         5.0           0.0     0.0
#
#    gain loss hours  income
# 1  2174    0    40     1.0
# 2     0    0    13     1.0
# 3     0    0    40     1.0
# 4     0    0    40     1.0
# 5     0    0    40     1.0

# %%
features = list(df.columns[:11])
features
# Out:
# ['age',
#  'class',
#  'education',
#  'years',
#  'married',
#  'occupation',
#  'relationship',
#  'gender',
#  'gain',
#  'loss',
#  'hours']

# %%
y = df['income']
X = df[features]
from sklearn.model_selection import train_test_split
pd.DataFrame(X).fillna(X.mean(), inplace = True)
pd.DataFrame(y).fillna(y.mean(), inplace = True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)
clf = tree.DecisionTreeClassifier(random_state = 50,max_depth=13, min_samples_leaf=5)
clf = clf.fit(X_train,y_train)

# %%
from IPython.display import Image
from sklearn.externals.six import StringIO
import pydotplus

dot_data = StringIO()
tree.export_graphviz(clf, out_file = dot_data, feature_names = features, class_names='income')
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
#Image(graph.create_png())
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.698642 to fit

# %%
preds = clf.predict(X_test)

# %%
y_test
# Out:
# 20163    0.0
# 9024     0.0
# 11083    0.0
# 7876     0.0
# 21403    1.0
# 14591    1.0
# 3171     1.0
# 13851    1.0
# 5122     0.0
# 19756    1.0
# 24088    1.0
# 9103     1.0
# 22279    1.0
# 6287     1.0
# 14330    1.0
# 22389    0.0
# 25552    1.0
# 15130    1.0
# 17292    1.0
# 25728    1.0
# 15982    1.0
# 1690     0.0
# 12086    1.0
# 10139    1.0
# 27870    1.0
# 18247    1.0
# 27751    0.0
# 30914    0.0
# 13735    1.0
# 11274    1.0
#         ...
# 7384     0.0
# 11600    1.0
# 22780    1.0
# 24823    1.0
# 19101    1.0
# 16265    0.0
# 15354    1.0
# 5752     1.0
# 14932    1.0
# 13293    0.0
# 13799    1.0
# 20340    1.0
# 8370     1.0
# 7874     1.0
# 26196    1.0
# 15657    1.0
# 8046     1.0
# 3384     1.0
# 14866    1.0
# 17297    1.0
# 24444    1.0
# 15144    0.0
# 14669    0.0
# 7347     1.0
# 10420    1.0
# 5128     1.0
# 819      1.0
# 3081     0.0
# 31320    1.0
# 8790     1.0
# Name: income, Length: 2973, dtype: float64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,preds)
# Out:
# 0.8631012445341406

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators = 10)
clf = clf.fit(X_train,y_train)
preds = clf.predict(X_test)
accuracy_score(y_test,preds)

#print clf.predict([[10,0,1,0,0,0,0,0,0,1,1]])
#print clf.predict([[10,4,1,0,0,0]])
# Out:
# 0.8432559704002691

# %%
clf.score(X_test,y_test)
# Out:
# 0.8432559704002691

# %%
model = GaussianNB()
model.fit(X_train, y_train)
preds=model.predict(X_test)

# %%
accuracy_score(y_test,preds)
# Out:
# 0.8008745375042045

# %%
from sklearn.neural_network import MLPClassifier

# %%
NN_Classifier = MLPClassifier()

# %%
NN_Classifier
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
NN_Classifier.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
preds = NN_Classifier.predict(X_test)
accuracy_score(y_test,preds)
# Out:
# 0.8314833501513622
